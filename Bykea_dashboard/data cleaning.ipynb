# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bykea_karachi_data_updated.csv')

# %%
df.head()
# Out:
#                   Date      Time Booking ID         Booking Status  \
# 0  2025-05-07 00:00:00  18:51:00   BK100000    Cancelled by Driver
# 1  2025-05-29 00:00:00  17:07:00   BK100001                Success
# 2  2025-05-16 00:00:00  20:09:00   BK100002  Cancelled by Customer
# 3  2025-05-18 00:00:00  17:42:00   BK100003  Cancelled by Customer
# 4  2025-05-18 00:00:00  07:11:00   BK100004                Success
#
#   Customer ID Vehicle Type     Pickup Location   Drop Location  Avg VTAT  \
# 0      CU9618   Prime Plus  Rashid Minhas Road          Landhi       NaN
# 1      CU2003  Prime Sedan  Shah Faisal Colony     New Karachi      9.66
# 2      CU8121         Mini             Clifton             DHA       NaN
# 3      CU6862   Prime Plus          Qayyumabad  Manzoor Colony       NaN
# 4      CU2163    Prime SUV              Saddar         Ancholi      2.25
#
#    Avg CTAT  Cancelled Rides by Customer  \
# 0       NaN                            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               100000 non-null  object
#  1   Time                               100000 non-null  object
#  2   Booking ID                         100000 non-null  object
#  3   Booking Status                     100000 non-null  object
#  4   Customer ID                        100000 non-null  object
#  5   Vehicle Type                       100000 non-null  object
#  6   Pickup Location                    100000 non-null  object
#  7   Drop Location                      100000 non-null  object
#  8   Avg VTAT                           62046 non-null   float64
#  9   Avg CTAT                           62046 non-null   float64
#  10  Cancelled Rides by Customer        100000 non-null  int64
# ...

# %%
df.duplicated().sum() #no duplicates
# Out:
# np.int64(0)

# %%
df['Cancelled Rides by Customer'].unique()
# Out:
# array([0, 1])

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'Avg VTAT',
#        'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Reason for cancelling by Driver', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Booking Value', 'Ride Distance',
#        'Driver Ratings', 'Customer Rating'],
#       dtype='object')

# %%
df.columns=df.columns.str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['date', 'time', 'booking_id', 'booking_status', 'customer_id',
#        'vehicle_type', 'pickup_location', 'drop_location', 'avg_vtat',
#        'avg_ctat', 'cancelled_rides_by_customer',
#        'reason_for_cancelling_by_customer', 'cancelled_rides_by_driver',
#        'reason_for_cancelling_by_driver', 'incomplete_rides',
#        'incomplete_rides_reason', 'booking_value', 'ride_distance',
#        'driver_ratings', 'customer_rating'],
#       dtype='object')

# %%
df['customer_rating'].unique()
# Out:
# array([nan, 4.9, 4.4, 4.5, 4. , 3.8, 3.6, 3.2, 4.7, 3.1, 3.7, 3.4, 4.1,
#        3.5, 4.8, 3. , 3.9, 4.2, 4.3, 5. , 4.6, 3.3])

# %%
df['reason_for_cancelling_by_customer'].fillna('Unkown Reasons',inplace=True)

# %%
df['reason_for_cancelling_by_driver']=df['reason_for_cancelling_by_driver'].fillna('Unkown Reasons')

# %%
for i in ['cancelled_rides_by_customer','cancelled_rides_by_driver','incomplete_rides']:
   df[i]= df[i].replace(1,'yes')
   df[i]= df[i].replace(0,'No')

# %%
df['cancelled_rides_by_driver'].unique()
# Out:
# array(['yes', 'No'], dtype=object)

# %%
df.head()
# Out:
#                   date      time booking_id         booking_status  \
# 0  2025-05-07 00:00:00  18:51:00   BK100000    Cancelled by Driver
# 1  2025-05-29 00:00:00  17:07:00   BK100001                Success
# 2  2025-05-16 00:00:00  20:09:00   BK100002  Cancelled by Customer
# 3  2025-05-18 00:00:00  17:42:00   BK100003  Cancelled by Customer
# 4  2025-05-18 00:00:00  07:11:00   BK100004                Success
#
#   customer_id vehicle_type     pickup_location   drop_location  avg_vtat  \
# 0      CU9618   Prime Plus  Rashid Minhas Road          Landhi       NaN
# 1      CU2003  Prime Sedan  Shah Faisal Colony     New Karachi      9.66
# 2      CU8121         Mini             Clifton             DHA       NaN
# 3      CU6862   Prime Plus          Qayyumabad  Manzoor Colony       NaN
# 4      CU2163    Prime SUV              Saddar         Ancholi      2.25
#
#    avg_ctat cancelled_rides_by_customer  \
# 0       NaN                          No
# ...

# %%
df.head()
# Out:
#                   date      time booking_id         booking_status  \
# 0  2025-05-07 00:00:00  18:51:00   BK100000    Cancelled by Driver
# 1  2025-05-29 00:00:00  17:07:00   BK100001                Success
# 2  2025-05-16 00:00:00  20:09:00   BK100002  Cancelled by Customer
# 3  2025-05-18 00:00:00  17:42:00   BK100003  Cancelled by Customer
# 4  2025-05-18 00:00:00  07:11:00   BK100004                Success
#
#   customer_id vehicle_type     pickup_location   drop_location  avg_vtat  \
# 0      CU9618   Prime Plus  Rashid Minhas Road          Landhi       NaN
# 1      CU2003  Prime Sedan  Shah Faisal Colony     New Karachi      9.66
# 2      CU8121         Mini             Clifton             DHA       NaN
# 3      CU6862   Prime Plus          Qayyumabad  Manzoor Colony       NaN
# 4      CU2163    Prime SUV              Saddar         Ancholi      2.25
#
#    avg_ctat cancelled_rides_by_customer  \
# 0       NaN                          No
# ...

# %%
df.columns
# Out:
# Index(['date', 'time', 'booking_id', 'booking_status', 'customer_id',
#        'vehicle_type', 'pickup_location', 'drop_location', 'avg_vtat',
#        'avg_ctat', 'cancelled_rides_by_customer',
#        'reason_for_cancelling_by_customer', 'cancelled_rides_by_driver',
#        'reason_for_cancelling_by_driver', 'incomplete_rides',
#        'incomplete_rides_reason', 'booking_value', 'ride_distance',
#        'driver_ratings', 'customer_rating'],
#       dtype='object')

# %%
df.to_csv('bykea_rides.csv',index=False)

# %%
#added new column to data bykea_rides
df2=pd.read_csv('bykea_rides.csv')

# %%
df2.head()
# Out:
#              date      time booking_id         booking_status customer_id  \
# 0   5/7/2025 0:00  18:51:00   BK100000    Cancelled by Driver      CU9618
# 1  5/29/2025 0:00  17:07:00   BK100001                Success      CU2003
# 2  5/16/2025 0:00  20:09:00   BK100002  Cancelled by Customer      CU8121
# 3  5/18/2025 0:00  17:42:00   BK100003  Cancelled by Customer      CU6862
# 4  5/18/2025 0:00   7:11:00   BK100004                Success      CU2163
#
#   vehicle_type     pickup_location   drop_location  avg_vtat  avg_ctat  ...  \
# 0   Prime Plus  Rashid Minhas Road          Landhi       NaN       NaN  ...
# 1  Prime Sedan  Shah Faisal Colony     New Karachi      9.66     13.72  ...
# 2         Mini             Clifton             DHA       NaN       NaN  ...
# 3   Prime Plus          Qayyumabad  Manzoor Colony       NaN       NaN  ...
# 4    Prime SUV              Saddar         Ancholi      2.25     11.14  ...
#
# ...

# %%
df2['Payment Method']
df2['booking_status'].unique()
# Out:
# array(['Cancelled by Driver', 'Success', 'Cancelled by Customer',
#        'Incomplete'], dtype=object)

# %%
df2['Payment Method'].unique()
# Out:
# array(['Cash', 'Wallet', 'Card'], dtype=object)

# %%
for i in range(0,len(df2),1):
    if df2.at[i,'booking_status']=='Success':
        df2.at[i,'Payment_Method']=np.random.choice(['Cash', 'Wallet', 'Card'])

# %%
df2.drop('Payment Method',axis=1,inplace=True)

# %%
df2.head()
# Out:
#              date      time booking_id         booking_status customer_id  \
# 0   5/7/2025 0:00  18:51:00   BK100000    Cancelled by Driver      CU9618
# 1  5/29/2025 0:00  17:07:00   BK100001                Success      CU2003
# 2  5/16/2025 0:00  20:09:00   BK100002  Cancelled by Customer      CU8121
# 3  5/18/2025 0:00  17:42:00   BK100003  Cancelled by Customer      CU6862
# 4  5/18/2025 0:00   7:11:00   BK100004                Success      CU2163
#
#   vehicle_type     pickup_location   drop_location  avg_vtat  avg_ctat  ...  \
# 0   Prime Plus  Rashid Minhas Road          Landhi       NaN       NaN  ...
# 1  Prime Sedan  Shah Faisal Colony     New Karachi      9.66     13.72  ...
# 2         Mini             Clifton             DHA       NaN       NaN  ...
# 3   Prime Plus          Qayyumabad  Manzoor Colony       NaN       NaN  ...
# 4    Prime SUV              Saddar         Ancholi      2.25     11.14  ...
#
# ...

# %%
df2[df2['booking_status']=='Success'][['booking_status','booking_value','Payment_Method']]
# Out:
#       booking_status  booking_value Payment_Method
# 1            Success        1339.72           Card
# 4            Success         202.65           Cash
# 5            Success        1209.87           Card
# 6            Success        1433.97           Cash
# 8            Success         715.94           Card
# ...              ...            ...            ...
# 99994        Success        1494.21         Wallet
# 99995        Success         585.36           Card
# 99997        Success         350.81           Cash
# 99998        Success        1218.78         Wallet
# 99999        Success         588.41           Cash
#
# [62046 rows x 3 columns]

# %%
df2.to_csv('bykea_rides.csv',index=False)
